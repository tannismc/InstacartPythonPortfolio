# %% [markdown]
# ## Tannis McCartney
# ## May 26, 2022
#
# ### This notbeok merges the orders_products and customers dataframes

# %% [markdown]
# ## Contents
# ### 01 Import Libraries
# ### 02 Import Orders and Products (with derivations and aggragations) dataset
# ### 03 Import Customers dataset
# ### 04 Merge all datasets
# ### 05 Export data

# %% [markdown]
# # 01 Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Import orders_products_aggragated dataset

# %%
# Turn project folder path into a string
path = r'C:\Users\tmmcc\Google Drive\Data Analytics Bootcamp\4 Python Fundamentals for Data Analysts\05-2022 Instacart Basket Analysis'

# %%
# Import orders_products_derived_aggragated.pkl
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_derived_aggregated.pkl'))
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered  ...        price_range     busiest_day  busiest_2_days  \
# ...

# %%
# Check the shape of df_ords_prods
df_ords_prods.shape
# Out:
# (32433030, 24)

# %%
# Check the data type of user_id
df_ords_prods['user_id'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# # 03 Import customers dataset

# %%
# Import customers.pkl
df_cust = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'customers.pkl'))
df_cust.head()
# Out:
#    user_id       state  age date_joined  dependants household_status  income
# 0    26711    Missouri   48    1/1/2017           3          married  165665
# 1    33890  New Mexico   36    1/1/2017           0           single   59285
# 2    65803       Idaho   35    1/1/2017           2          married   99568
# 3   125935        Iowa   40    1/1/2017           0           single   42049
# 4   130797    Maryland   26    1/1/2017           1          married   40374

# %%
# Check the shape of df_cust
df_cust.shape
# Out:
# (206209, 7)

# %%
# Check the data type of user_id
df_cust['user_id'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# # 04 Merge datasets

# %%
# Merge dataframes based on user_id
df_all = df_ords_prods.merge(df_cust, on='user_id', indicator = True)
df_all.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered  ... spending_flag  median_days_since_order  \
# ...

# %%
# Check shape of df_all
df_all.shape
# Out:
# (32433030, 31)

# %% [markdown]
# # 05 Export data

# %%
# Remove _merge column from data
df_all = df_all.drop(columns=['_merge'])

# %%
# Export df_all to pkl
df_all.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_all.pkl'))
